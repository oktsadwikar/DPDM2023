# %% [markdown]
# <a href="https://colab.research.google.com/github/oktsadwikar/DPDM2023/blob/main/Data102(Chapter_2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading the data
#
# - directly upload
# - mouting GDrive

# %% [markdown]
# # Directly upload (temporary)

# %%
import pandas

# %%
table1 = pandas.read_csv('/content/csv')

# %%
table1
# Out:
#        Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0      ตุลาคม   2565                 95                18
# 1   พฤศจิกายน   2565                 95                20
# 2     ธันวาคม   2565                 94                18
# 3      มกราคม   2566                 94                18
# 4  กุมภาพันธ์   2566                100                20
# 5      มีนาคม   2566                100                22
# 6      เมษายน   2566                100                17
# 7     พฤษภาคม   2566                101                26
# 8    มิถุนายน   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %%
table1.shape #to know the number of row and column
# Out:
# (9, 9)

# %% [markdown]
# # Mounting with GDrive

# %%
# mounting colab with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
table_from_drive = pandas.read_csv('/content/drive/MyDrive/DPDM23_DATA/csv')
table_from_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 70                17
# 7        Mei   2566                101                26
# 8       June   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# # 1 Eyesball the Data

# %%
table_from_drive.shape
# Out:
# (9, 9)

# %%
table_from_drive.describe() #Descriptive Statistics
# Out:
#              Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# count     9.000000           9.000000          9.000000              9.000000
# mean   2565.666667          94.444444         20.444444             35.222222
# std       0.500000           9.658042          3.244654             10.521143
# min    2565.000000          70.000000         17.000000             27.000000
# 25%    2565.000000          94.000000         18.000000             28.000000
# 50%    2566.000000          95.000000         20.000000             30.000000
# 75%    2566.000000         100.000000         22.000000             39.000000
# max    2566.000000         101.000000         26.000000             57.000000
#
#        Amount_ Personalleave  Amount_ Day_Personalleave  \
# count               9.000000                   9.000000
# mean                1.666667                   2.888889
# std                 1.000000                   1.746027
# ...

# %%
table_from_drive.head()  #to show the top 5 of the data
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
#
#    Amount_ Vacationleave  Amount_ Day_Vacationleave
# 0                     35                       57.0
# 1                     31                       47.0
# ...

# %%
table_from_drive.tail()  #to show the bottom 5 of the data
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 70                17
# 7        Mei   2566                101                26
# 8       June   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 4                    30                      2                        5.0
# 5                    33                      2                        4.0
# 6                    29                      1                        1.0
# 7                    47                      1                        2.0
# 8                    39                      2                        3.0
#
#    Amount_ Vacationleave  Amount_ Day_Vacationleave
# 4                     32                       60.0
# 5                     47                       75.0
# ...

# %%
table_from_drive.head(7)  #to show the top 7 (number inside the ()) of the data
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 70                17
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
# ...

# %% [markdown]
# ## Data Selection (indexing and slicing)

# %% [markdown]
# ### Table View

# %%
table_from_drive['Amount_Government'][2]  #Indexing = want to see column Amount Goverment and row 2 (start from 0)
# Out:
# 94

# %%
table_from_drive['Amount_Government'][:2]  #column slicing = want to see column Amount Goverment and row 0,1
# Out:
# 0    95
# 1    95
# Name: Amount_Government, dtype: int64

# %%
table_from_drive[['Amount_Government','Amount_Day_Sickleave']] #column slicing = create new table, this is not change the table
# Out:
#    Amount_Government  Amount_Day_Sickleave
# 0                 95                    28
# 1                 95                    57
# 2                 94                    27
# 3                 94                    27
# 4                100                    30
# 5                100                    33
# 6                 70                    29
# 7                101                    47
# 8                101                    39

# %%
new_table = table_from_drive[['Amount_Government','Amount_Day_Sickleave']]

# %%
new_table
# Out:
#    Amount_Government  Amount_Day_Sickleave
# 0                 95                    28
# 1                 95                    57
# 2                 94                    27
# 3                 94                    27
# 4                100                    30
# 5                100                    33
# 6                 70                    29
# 7                101                    47
# 8                101                    39

# %% [markdown]
# ### Array View

# %%
table_from_drive.iloc[2,2] #indexing with array view, to call/see array from row no 2 and column no 2 (row/column number start from 0)
# Out:
# 94

# %%
table_from_drive.iloc[2:8,2:8:2] #slicing
# Out:
#    Amount_Government  Amount_Day_Sickleave  Amount_ Day_Personalleave
# 2                 94                    27                        4.5
# 3                 94                    27                        4.5
# 4                100                    30                        5.0
# 5                100                    33                        4.0
# 6                 70                    29                        1.0
# 7                101                    47                        2.0

# %% [markdown]
# ## Assign value to pandas *DataFrame*

# %% [markdown]
# ### 1. Standard Method

# %% [markdown]
# ``` loc ``` command for point and change the value

# %%
table_from_drive.loc[6,'Amount_Government']=83

# %%
table_from_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 83                17
# 7        Mei   2566                101                26
# 8       June   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# ### 2. Table View

# %%
table_from_drive['Amount_Government'][6] = 84
# Out:
# <ipython-input-84-025bcee2802a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table_from_drive['Amount_Government'][6] = 84

# %%
table_from_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 84                17
# 7        Mei   2566                101                26
# 8       June   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# ### 3. Array View

# %%
table_from_drive.iloc[-3,2]=83

# %%
table_from_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 83                17
# 7        Mei   2566                101                26
# 8       June   2566                101                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# # 2. Boxplot
#
# ![image.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt #Library : matplotlib, pocket = pyplot, rename as plt

# %% [markdown]
# cara lain : ```import matplotlib.pyplot as plt```

# %%
table_from_drive['Amount_Government']
# Out:
# 0     95
# 1     95
# 2     94
# 3     94
# 4    100
# 5    100
# 6     83
# 7    101
# 8    101
# Name: Amount_Government, dtype: int64

# %%
plt.boxplot(table_from_drive['Amount_Government'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c7cc02b1cf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c7cc02b1660>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c7cc02b3100>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c7cc02b24a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c7cc02b1f60>],
#  'means': []}

# %%
plt.boxplot(table_from_drive['Amount_Government']); #pakai ; untuk menghilangkan tulisan

# %%
plt.boxplot(table_from_drive['Amount_ Day_Vacationleave']);

# %% [markdown]
# ## Take Values from the boxplot

# %%
boxplot_output = plt.boxplot(table_from_drive['Amount_Government'])

# %%
boxplot_output  #type of structure of this output is dictionary
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c7cbff35e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c7cc043de10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c7cbff34f10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c7cc043ff10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c7cbff0e170>],
#  'means': []}

# %%
boxplot_output['fliers'] #call fliers so this is a list

# %%
boxplot_output['fliers'][0]  #fliers = outlier, and use [0] take the value inside the list

# %%
boxplot_output['fliers'][0].get_ydata()  #from the value before, we can get the value of y and x. this time we get y velue and the data still in array
# Out:
# array([83])

# %%
boxplot_output['fliers'][0].get_ydata()[0] #using [0] after get_ydata is for take the value inside array, so the type is not array anymore
# Out:
# 83

# %% [markdown]
# *add an outlier*

# %%
table_from_drive.iloc[-1,2]=130

# %%
table_from_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 83                17
# 7        Mei   2566                101                26
# 8       June   2566                130                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %%
boxplot_output = plt.boxplot(table_from_drive['Amount_Government'])

# %%
boxplot_output  #type of structure of this output is dictionary
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c7cc0127640>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c7cc0127c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c7cc0127490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c7cc015c1c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c7cc015c460>],
#  'means': []}

# %%
boxplot_output['fliers'] #call fliers so this is a list

# %%
boxplot_output['fliers'][0]  #fliers = outlier, and use [0] take the value inside the list

# %%
boxplot_output['fliers'][0].get_ydata()  #from the value before, we can get the value of y and x. this time we get y velue and the data still in array
# Out:
# array([ 83, 130])

# %%
boxplot_output['fliers'][0].get_ydata()[0] #using [0] after get_ydata is for take the value inside array of index number 0
# Out:
# 83

# %%
boxplot_output['fliers'][0].get_ydata()[1] #using [0] after get_ydata is for take the value inside array of index number 0
# Out:
# 130

# %% [markdown]
# # Querying and Filtering

# %% [markdown]
# ```python
# DataFrame[list_of_logics]  #len(list_of_logics) = len(DataFrame
# ```
#
# list_of_logics is True or False. True = you want the data, False = you don't want the data

# %%
table_from_drive[[False,False,False,True,False,True,False,False,False]]  #we want to Jan and March
# Out:
#     Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 3  January   2566                 94                18                    27
# 5    March   2566                100                22                    33
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 3                      3                        4.5                     47
# 5                      2                        4.0                     47
#
#    Amount_ Day_Vacationleave  Amount_Goverment
# 3                       69.5               NaN
# 5                       75.0               NaN

# %% [markdown]
# ## Creating list_of_logics

# %%
table_from_drive
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 6      April   2566                 83                17
# 7        Mei   2566                101                26
# 8       June   2566                130                25
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# ...

# %% [markdown]
# all rows that have amount_sickleave equal to 20

# %%
table_from_drive['Amount_Sickleave'] == 20
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# Name: Amount_Sickleave, dtype: bool

# %%
table_from_drive[table_from_drive['Amount_Sickleave'] == 20]
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 1   November   2565                 95                20
# 4  F์ebruary   2566                100                20
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 1                    57                      0                        0.0
# 4                    30                      2                        5.0
#
#    Amount_ Vacationleave  Amount_ Day_Vacationleave  Amount_Goverment
# 1                     31                       47.0               NaN
# 4                     32                       60.0               NaN

# %% [markdown]
# # Quiz 3
#
# filter out the outlier rows ($'Amount\_Goverment'$)

# %% [markdown]
# ***Answer***

# %%
table_from_drive[(table_from_drive['Amount_Government'] != boxplot_output['fliers'][0].get_ydata()[0]) & (table_from_drive['Amount_Government'] != boxplot_output['fliers'][0].get_ydata()[1])]
# Out:
#       Month_  Year_  Amount_Government  Amount_Sickleave  \
# 0    October   2565                 95                18
# 1   November   2565                 95                20
# 2   December   2565                 94                18
# 3    January   2566                 94                18
# 4  F์ebruary   2566                100                20
# 5      March   2566                100                22
# 7        Mei   2566                101                26
#
#    Amount_Day_Sickleave  Amount_ Personalleave  Amount_ Day_Personalleave  \
# 0                    28                      1                        2.0
# 1                    57                      0                        0.0
# 2                    27                      3                        4.5
# 3                    27                      3                        4.5
# 4                    30                      2                        5.0
# ...
